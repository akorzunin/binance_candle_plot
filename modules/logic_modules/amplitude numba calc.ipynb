# %%
import pandas as pd
import numpy as np
import pickle
import os
from dotenv import load_dotenv
load_dotenv()
PWD = os.getenv('PWD')
db_name = PWD+'\\database'+'\\RVNUSDT.db'
import sys
sys.path.insert(1, PWD+'\\modules')

# %%
df = pd.read_sql(
    '''
        SELECT * FROM m5 
        WHERE date_created > "2021-12-00 00:00:00.000000"
    ''',
    'sqlite:///' + db_name, 
    index_col='id',
)
len(df)
# Out:
# 8800

# %%
# %%timeit -n 10
for i, row in df.iterrows():
    df.loc[i, 'amplitude'] = (float(row['high_']) - float(row['low_']))/float(row['low_'])*100

# %%
# %%timeit -n 10
for i, row in df.iterrows():
    df.loc[i, 'amplitude'] = (np.float64(row['high_']) - np.float64(row['low_']))/np.float64(row['low_'])*100
# Out:
# 3.96 s ± 82.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit 
for i, row in df.iterrows():
    df.loc[i, 'amplitude'] = (np.float64(row['high_']) - np.float64(row['low_']))/np.float64(row['low_'])*np.uint8(100)
# Out:
# 3.82 s ± 99.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
from numba import njit

# @njit
# # def njit_():
# for i, row in df.iterrows():
#     df.loc[i, 'amplitude'] = (np.float64(row['high_']) - np.float64(row['low_']))/np.float64(row['low_'])*np.uint8(100)

# %%
import numba


@numba.njit
def amplitude_f_numba(a, b, ):
    return (a - b) / b * 100
    # return (np.float64(a) - np.float64(b))/np.float64(b)*np.uint8(100)


@numba.njit
def apply_amplitude_f_numba(col_high_, col_low_, ):
    n = len(col_high_)
    result = np.empty(n, dtype="float64")
    assert len(col_high_) == len(col_low_) == n
    for i in range(n):
        result[i] = amplitude_f_numba(col_high_[i], col_low_[i], )
    return result


def compute_numba(df):
    result = apply_amplitude_f_numba(
        df["high_"].to_numpy(dtype='float64'), 
        df["low_"].to_numpy(dtype='float64'), 
    )
    df['amplitude'] = pd.Series(result, index=df.index, )
    return df

# %%
import cProfile

# %%
# %%timeit -n 100
# %prun compute_numba(df)
# Out:
#          468 function calls (460 primitive calls) in 0.007 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         4    0.005    0.001    0.005    0.001 {built-in method numpy.array}
#         1    0.000    0.000    0.001    0.001 blocks.py:2711(make_block)
#         1    0.000    0.000    0.000    0.000 managers.py:1057(iset)
#         1    0.000    0.000    0.000    0.000 3413057701.py:10(apply_amplitude_f_numba)
#         1    0.000    0.000    0.007    0.007 3413057701.py:20(compute_numba)
#         2    0.000    0.000    0.000    0.000 managers.py:998(iget)
#         2    0.000    0.000    0.001    0.000 frame.py:2987(__getitem__)
#         3    0.000    0.000    0.001    0.000 series.py:238(__init__)
#         2    0.000    0.000    0.000    0.000 generic.py:3783(_get_item_cache)
#        76    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.007    0.007 {built-in method builtins.exec}
#         7    0.000    0.000    0.000    0.000 generic.py:5467(__setattr__)
#         2    0.000    0.000    0.000    0.000 generic.py:5411(__finalize__)
#         4    0.000    0.000    0.000    0.000 base.py:4230(__contains__)
#         3    0.000    0.000    0.000    0.000 blocks.py:127(__init__)
#         3    0.000    0.000    0.000    0.000 generic.py:188(__init__)
#         2    0.000    0.000    0.005    0.003 base.py:503(to_numpy)
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 blocks.py:354(set_inplace)
#         3    0.000    0.000    0.000    0.000 blocks.py:269(mgr_locs)
#     29/21    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         3    0.000    0.000    0.000    0.000 base.py:3036(get_loc)
#         3    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         2    0.000    0.000    0.000    0.000 frame.py:3306(_box_col_values)
#         7    0.000    0.000    0.000    0.000 common.py:1470(is_extension_array_dtype)
#         2    0.000    0.000    0.000    0.000 base.py:4279(__getitem__)
#         3    0.000    0.000    0.000    0.000 series.py:488(name)
#         1    0.000    0.000    0.000    0.000 cast.py:1257(maybe_castable)
#         3    0.000    0.000    0.000    0.000 series.py:538(name)
#         3    0.000    0.000    0.000    0.000 base.py:5287(_maybe_cast_indexer)
#         2    0.000    0.000    0.000    0.000 blocks.py:351(iget)
#         1    0.000    0.000    0.000    0.000 blocks.py:2662(get_block_type)
#         1    0.000    0.000    0.000    0.000 construction.py:423(sanitize_array)
#         3    0.000    0.000    0.000    0.000 series.py:439(_set_axis)
#         1    0.000    0.000    0.000    0.000 _dtype.py:321(_name_get)
#         2    0.000    0.000    0.000    0.000 blocks.py:288(make_block_same_class)
#         3    0.000    0.000    0.000    0.000 flags.py:47(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:3833(_sanitize_column)
#         3    0.000    0.000    0.000    0.000 managers.py:1545(__init__)
#        20    0.000    0.000    0.000    0.000 generic.py:30(_check)
#         1    0.000    0.000    0.000    0.000 shape_base.py:82(atleast_2d)
#         3    0.000    0.000    0.005    0.002 _asarray.py:23(asarray)
#         2    0.000    0.000    0.000    0.000 common.py:201(is_object_dtype)
#         1    0.000    0.000    0.000    0.000 frame.py:3147(__setitem__)
#         3    0.000    0.000    0.000    0.000 generic.py:5449(__getattr__)
#         3    0.000    0.000    0.000    0.000 common.py:1743(validate_all_hashable)
#         5    0.000    0.000    0.000    0.000 common.py:129(cast_scalar_indexer)
#         7    0.000    0.000    0.000    0.000 base.py:411(find)
#         3    0.000    0.000    0.000    0.000 blocks.py:161(_check_ndim)
#         2    0.000    0.000    0.000    0.000 blocks.py:2505(_maybe_coerce_values)
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.001    0.001 managers.py:1577(from_array)
#         1    0.000    0.000    0.000    0.000 frame.py:3231(_set_item)
#         3    0.000    0.000    0.000    0.000 base.py:1875(is_floating)
#         6    0.000    0.000    0.000    0.000 inference.py:322(is_hashable)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         1    0.000    0.000    0.000    0.000 construction.py:612(is_empty_data)
#        35    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 common.py:231(is_sparse)
#         1    0.000    0.000    0.000    0.000 frame.py:3853(reindexer)
#         3    0.000    0.000    0.000    0.000 managers.py:1626(internal_values)
#         6    0.000    0.000    0.000    0.000 common.py:1762(<genexpr>)
#         3    0.000    0.000    0.000    0.000 common.py:317(apply_if_callable)
#         2    0.000    0.000    0.000    0.000 flags.py:83(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 generic.py:3824(_set_item)
#         3    0.000    0.000    0.000    0.000 series.py:585(_values)
#         4    0.000    0.000    0.000    0.000 base.py:254(is_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:537(is_categorical_dtype)
#         7    0.000    0.000    0.000    0.000 base.py:600(__len__)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000    0.000    0.000 generic.py:3820(_iset_item)
#         2    0.000    0.000    0.000    0.000 managers.py:1615(dtype)
#         2    0.000    0.000    0.000    0.000 generic.py:3409(_set_as_cached)
#         1    0.000    0.000    0.000    0.000 indexing.py:2204(convert_to_index_sliceable)
#         1    0.000    0.000    0.007    0.007 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 _dtype.py:307(_name_includes_bit_suffix)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 numerictypes.py:359(issubdtype)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:285(issubclass_)
#         1    0.000    0.000    0.000    0.000 dtypes.py:1132(is_dtype)
#         3    0.000    0.000    0.000    0.000 managers.py:173(blklocs)
#         2    0.000    0.000    0.000    0.000 common.py:1610(_is_dtype_type)
#         1    0.000    0.000    0.000    0.000 generic.py:3485(_clear_item_cache)
#         1    0.000    0.000    0.000    0.000 common.py:499(is_interval_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:5953(maybe_extract_name)
#         1    0.000    0.000    0.000    0.000 managers.py:206(shape)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         1    0.000    0.000    0.000    0.000 dtypes.py:923(is_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:573(is_string_dtype)
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         5    0.000    0.000    0.000    0.000 managers.py:1588(_block)
#         2    0.000    0.000    0.000    0.000 series.py:473(dtype)
#         3    0.000    0.000    0.000    0.000 managers.py:157(blknos)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         2    0.000    0.000    0.000    0.000 construction.py:354(extract_array)
#         1    0.000    0.000    0.000    0.000 blocks.py:719(should_store)
#         1    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 blocks.py:347(dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.000    0.000    0.000    0.000 common.py:463(is_period_dtype)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 construction.py:554(_try_cast)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         1    0.000    0.000    0.000    0.000 common.py:615(is_dtype_equal)
#         2    0.000    0.000    0.000    0.000 common.py:1575(get_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:388(is_datetime64tz_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:185(classes)
#         1    0.000    0.000    0.000    0.000 base.py:4393(equals)
#         2    0.000    0.000    0.000    0.000 flags.py:51(allows_duplicate_labels)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 blocks.py:265(mgr_locs)
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 frame.py:1158(__len__)
#         2    0.000    0.000    0.000    0.000 generic.py:227(attrs)
#         1    0.000    0.000    0.000    0.000 _asarray.py:110(asanyarray)
#         1    0.000    0.000    0.000    0.000 frame.py:3284(_ensure_valid_index)
#         4    0.000    0.000    0.000    0.000 generic.py:248(flags)
#         3    0.000    0.000    0.000    0.000 blocks.py:233(internal_values)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         1    0.000    0.000    0.000    0.000 base.py:5836(ensure_index)
#         3    0.000    0.000    0.000    0.000 managers.py:208(<genexpr>)
#         1    0.000    0.000    0.000    0.000 generic.py:545(_info_axis)
#         1    0.000    0.000    0.000    0.000 managers.py:1085(value_getitem)
#         3    0.000    0.000    0.000    0.000 numeric.py:164(_is_all_dates)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 common.py:187(<lambda>)
#         1    0.000    0.000    0.000    0.000 generic.py:3863(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 managers.py:210(ndim)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         1    0.000    0.000    0.000    0.000 shape_base.py:78(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 base.py:532(is_)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 common.py:1551(_is_dtype)
#         1    0.000    0.000    0.000    0.000 blocks.py:147(_maybe_coerce_values)

# %%
df = compute_numba(df)
df
# Out:
#                       date_created      open_time       open_       high_  \
# id
# 230292  2021-12-01 00:00:00.000000  1638306000000  0.10843000  0.10899000
# 230293  2021-12-01 00:05:00.000000  1638306300000  0.10882000  0.10884000
# 230294  2021-12-01 00:10:00.000000  1638306600000  0.10850000  0.10866000
# 230295  2021-12-01 00:15:00.000000  1638306900000  0.10863000  0.10888000
# 230296  2021-12-01 00:20:00.000000  1638307200000  0.10856000  0.10862000
# ...                            ...            ...         ...         ...
# 239087  2021-12-31 09:20:00.000000  1640931600000  0.09453000  0.09492000
# 239088  2021-12-31 09:25:00.000000  1640931900000  0.09490000  0.09501000
# 239089  2021-12-31 09:30:00.000000  1640932200000  0.09477000  0.09502000
# 239090  2021-12-31 09:35:00.000000  1640932500000  0.09501000  0.09522000
# 239091  2021-12-31 09:40:00.000000  1640932800000  0.09522000  0.09611000
#
#               low_      close_           volume_     close_time  \
# id
# 230292  0.10841000  0.10882000   383820.00000000  1638306299999
# 230293  0.10836000  0.10849000   226955.20000000  1638306599999
# 230294  0.10849000  0.10863000   242321.70000000  1638306899999
# 230295  0.10850000  0.10856000   221322.50000000  1638307199999
# 230296  0.10840000  0.10843000   906280.40000000  1638307499999
# ...            ...         ...               ...            ...
# 239087  0.09446000  0.09487000   317678.80000000  1640931899999
# 239088  0.09474000  0.09480000   166964.50000000  1640932199999
# 239089  0.09476000  0.09501000   133066.90000000  1640932499999
# 239090  0.09493000  0.09520000   200918.30000000  1640932799999
# 239091  0.09510000  0.09512000  1718777.60000000  1640933099999
#
#        quote_asset_volume number_of_trades taker_buy_base_asset_volume  \
# id
# 230292     41754.49734100               91             263645.70000000
# 230293     24651.80424200               89              82917.70000000
# 230294     26306.41257500               99             151675.20000000
# 230295     24050.57299600               93             140344.10000000
# 230296     98337.47837400              150             295507.90000000
# ...                   ...              ...                         ...
# 239087     30068.68891200              160             234649.00000000
# 239088     15836.15077100               94              45538.50000000
# 239089     12633.91783700               90              61023.20000000
# 239090     19097.38251500              112             125454.40000000
# 239091    164357.98702800              693            1181934.60000000
#
#        taker_buy_quote_asset_volume ignore_  amplitude
# id
# 230292               28680.24724400       0   0.535006
# 230293                9009.24099600       0   0.442968
# 230294               16465.62420300       0   0.156696
# 230295               15249.74851800       0   0.350230
# 230296               32068.47470500       0   0.202952
# ...                             ...     ...        ...
# 239087               22216.13319500       0   0.486979
# 239088                4321.94835700       0   0.284991
# 239089                5794.23222500       0   0.274377
# 239090               11927.52886900       0   0.305488
# 239091              113063.56104500       0   1.062040
#
# [8800 rows x 14 columns]
